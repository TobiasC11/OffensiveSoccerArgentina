# %%
import pandas as pd
import LanusStats as ls
fotmob = ls.FotMob()

# %%
estadisticas = list(fotmob.team_possible_stats)

# %%
all_data = []
for stat in estadisticas:
    df_coparcha = pd.read_csv(rf"C:\Tobias\Docs\StrikerP\Datos\Fotmob\teams\Copa de Ligarcha\{stat}_Argentina_Copa_de_la_Liga.csv")
    df_ligarcha = pd.read_csv(rf"c:\Tobias\Docs\StrikerP\Datos\Fotmob\teams\Liga\{stat}_Argentina_Primera_Division.csv")
    union = pd.concat([df_coparcha, df_ligarcha])
    union.to_csv(f"{stat}_Argentina.csv", index=False)
    all_data.append(union)

# %%
all_data[7]
# Out:
#          id  teamId         team_name  rank   type        stat_name  value  \
# 0     10076   10076       River Plate     1  teams  big_chance_team     58
# 1     10077   10077      Boca Juniors     2  teams  big_chance_team     51
# 2     10094   10094       Estudiantes     3  teams  big_chance_team     40
# 3     10090   10090         Instituto     4  teams  big_chance_team     40
# 4     10227   10227        Godoy Cruz     5  teams  big_chance_team     40
# ..      ...     ...               ...   ...    ...              ...    ...
# 105  161727  161727  Atletico Tucuman    22  teams  big_chance_team     35
# 106   10078   10078     Independiente    23  teams  big_chance_team     34
# 107   10083   10083       San Lorenzo    24  teams  big_chance_team     33
# 108  202757  202757         Sarmiento    25  teams  big_chance_team     32
# 109   10098   10098   Arsenal Sarandi    26  teams  big_chance_team     26
#
#      sub_value                      League  Season
# ...

# %%
union
# Out:
#          id  teamId               team_name  rank   type            stat_name  \
# 0     10078   10078           Independiente     1  teams  accurate_cross_team
# 1     10103   10103             Gimnasia LP     2  teams  accurate_cross_team
# 2    161727  161727        Atletico Tucuman     3  teams  accurate_cross_team
# 3     10096   10096                   Union     4  teams  accurate_cross_team
# 4     10090   10090               Instituto     5  teams  accurate_cross_team
# ..      ...     ...                     ...   ...    ...                  ...
# 105   10089   10089  Club Atletico Platense    22  teams  accurate_cross_team
# 106  161728  161728                Aldosivi    23  teams  accurate_cross_team
# 107  161730  161730      Defensa y Justicia    24  teams  accurate_cross_team
# 108   10088   10088                   Colon    25  teams  accurate_cross_team
# 109   10103   10103             Gimnasia LP    26  teams  accurate_cross_team
#
# ...
